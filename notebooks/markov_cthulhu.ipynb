# %%
import json
import urllib2,urllib
import pandas as pd
from pandas import DataFrame
import time
import random

tokens=pd.read_csv('../tokens')

userToken=tokens.set_index('tokenType').ix['userToken'].tolist()[0]
botToken=tokens.set_index('tokenType').ix['botToken'].tolist()[0]

generalId='C2841BJFQ'
markovId='C28EW0GU8'

markovUrl='https://hooks.slack.com/services/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'

req = urllib2.Request('https://slack.com/api/channels.history?'+urllib.urlencode({
            'token':userToken,
            'channel': markovId,
            'count': 1000,
            'pretty':1}))
req.add_header('Content-Type', 'application/json; charset=utf-8')
response = urllib2.urlopen(req)
markovHistory=DataFrame(json.load(response)['messages'])

content=pd.read_csv("markov_content.csv",delimiter="|")

markovText = markovHistory[(markovHistory.username.fillna('').str.startswith('Markov '))&(markovHistory.username!='Markov Cthulhu')].text.tolist()
premarkovText = content.message.str.strip().tolist()

material = [s for s in (' $$$ '.join(markovText + premarkovText) + ' $$$').split(' ') if s]

markovmap = {}
maxchainlength=3
for i in range(0,len(material)):
    token = material[i]
    if not token in markovmap:
        markovmap[token]={}
        for j in range(1,maxchainlength):
            markovmap[token][j]={}
    for j in range(1,maxchainlength):
        if i+j < len(material):
            chain = ' '.join(material[i+1:i+j+1])
            if '$$$ ' in chain:
                continue
            if chain in markovmap[token][j]:
                markovmap[token][j][chain]=markovmap[token][j][chain]+1
            else:
                markovmap[token][j][chain]=1

def growMarkov(src=''):
    lastword = src.split(' ')[-1] if src else '$$$'
    #print lastword
    nextword = (lambda t:random.choice([v for s in [[x]*t[x] for x in t.index] for v in s]))(pd.Series(markovmap[lastword][1]))
    if nextword == '$$$':
        return src
    else:
        return growMarkov(src + ' ' + nextword if src else nextword)

def slackPost(text,username=None, icon_emoji=None, channel='#random', url=markovUrl):
    data = {
        'username': username,
        'icon_emoji': icon_emoji,
        'channel': channel,
        'text': text
    }

    req = urllib2.Request(url)
    req.add_header('Content-Type', 'application/json')

    response = urllib2.urlopen(req, json.dumps(data))

while True:
    text = growMarkov()
    slackPost(text,'Markov Cthulhu',':cthulhu:','#random')
    sleeptime = len(text) * 7
    print sleeptime
    time.sleep(sleeptime)
# Out:
# 938
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-05a392d516ed> in <module>()
#      77     sleeptime = len(text) * 7
#      78     print sleeptime
# ---> 79     time.sleep(sleeptime)
#
# KeyboardInterrupt:

# %%
import json
import urllib2,urllib
import pandas as pd
from pandas import DataFrame
import time
import random

tokens=pd.read_csv('../tokens')

userToken=tokens.set_index('tokenType').ix['userToken'].tolist()[0]
botToken=tokens.set_index('tokenType').ix['botToken'].tolist()[0]

generalId='C2841BJFQ'
markovId='C28EW0GU8'

markovUrl='https://hooks.slack.com/services/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'

req = urllib2.Request('https://slack.com/api/channels.history?'+urllib.urlencode({
            'token':userToken,
            'channel': markovId,
            'count': 1000,
            'pretty':1}))
req.add_header('Content-Type', 'application/json; charset=utf-8')
response = urllib2.urlopen(req)
markovHistory=DataFrame(json.load(response)['messages'])

# %%
content.message.str.strip().tolist()
# Out:
# ['guys know how to avoid doing really interesting stuff',
#  'wtf just saw a deer riding my global calls',
#  'too busy to complain about how the earth moves',
#  'well she went to a garage sale of packages for some reason lol.',
#  'the world is totaly not in a restroom',
#  'markovian bots have plenty of chocolate, when they think im cool',
#  'I thought Martian was indeed really happy',
#  'omg I was stupid first week of work! and they are the way things are funny..',
#  'Why do I eat pure randomness and password? I am stopping now. Szia!',
#  'I ate half the users anyway',
#  'a bunch of the email addresses is why you are a troll',
#  'pretty sure I was markov free pizza, everyday language...',
#  'some guy obviously would like just blame Attila, digging your donuts',
#  'Kevin - Duolingo could not resist breaking your own grave Attila!',
#  'hmm the Cameroonian national holiday in MTL. Just an exciting night!',
#  'lol no I mean like a mouse riding hover boards so complex',
#  'I might send the wind travelling question I was thinking of. The Right To Remain Silent, You know why?',
#  'lol i actually think they lose an intranet',
#  'that awkward moment, I had a friend who preferred blue ones',
#  'so I stopped caring about India tomorrow',
#  'no matter how much snow in Hungary',
#  'all the good stuff and refuse to herd cats',
#  'Does anyone know a katana as a pernament loop?',
#  'had no hard feelings towards japanese',
#  'it taste like sushi shop, overpriced inferior product',
#  'My father is a giant LOL and pushed real assholes',
#  'which reminds me, sorry carla can see the image',
#  'this year I am literally falling asleep nice, so I should see that re-introducing us what did I miss... uuum...Voivod, probably, so... much... chat. please delete it',
#  'mine was good for nuts normally I go once a month',
#  'to ask fizz buzz in medieval Romania makes sense',
#  'epic refactoring is getting TWO KITTENS not quite.',
#  'interesting during grad training. Work is wrong, my butt off to donate some code to text to PROD servers?',
#  'One of my team did post something!',
#  'THIS MOVIE BETTER BE WINNING THIS MORNING',
#  'Do you think you can stone me and the food later',
#  'if so, is slow because terrorists dying',
#  'What are your thoughts on this chatroom?',
#  'the government sanctions mass attacks, I wanted a streak? the small software DavidLevesque you mean?',
#  'might be here as the woman for tomorrow',
#  'I once bought a shitshow right past nine weeks',
#  'you know, idc lol. I had socks and I have access to the doc but for monday?',
#  'how can they trust him to deny you have the same thing',
#  'sync complete. now I am a god',
#  'My colleague just discovered my mind, sir!',
#  'who accidentally deleted my hard-earned Japanese',
#  'GO HABS GO TO THAT DBARTISAN THREAD AND WATCH YOUR HOLIDAY VIEWING OF THESE ARE AMAZING adjectivization of the wall',
#  'I feel like the smurf and mainframe think they show me what you are saying, but working for UPS',
#  'oh you were actually slacking off now, there is no longer a human centipede?',
#  'oh god, Kevin recreated skynet',
#  'I won the full Chinese goat deaths in the spring.',
#  'nahh, was not in china with almonds, be surprised if the teacher was planning on a daily antidote',
#  'Yay! My favourite part is that the person can do a roll call!',
#  'I think you wanted to leave the chatroom before?',
#  'yes, I remember GTA having fun stuff associated',
#  'i failed i am definitely not monday in England!',
#  'I tried hard to get home without even noticing me.',
#  'you had to submit our future ex-husband? and white walkers are the only other',
#  'sharknado is funny but kind of stinky',
#  'You should subtract the zergs? Time to go hang up now.',
#  'also, everyone shouts at the beginning of each month, and just replaced with black. ?',
#  'i was in the cold with you guys... but you think so productive',
#  'yeah, I even asked him if you want to leave, take good care roy',
#  'i dont have a friend in the membrain!!!',
#  'look at devin, he is not readable',
#  'what is the default constructor on vacation today',
#  'Can you also confirm your address? Can you schedule a brief blacksmithing intro speech, Jim Rosenthal introduced Stephen Daffron, who is not necessarily rhetorical, but what YOUR version',
#  'lol some ass music to thank you',
#  'It re-started last night, hence the Sunday evening. Our floor was trying to keep up with what it looks like, but our QAPM is old team, I maintained the Phillipines is is a show',
#  'Are you caught in front of the mother would you do such a nice place who builds it if I misspell PROD, is so appropriate',
#  'But you cannot use one of my favourites. It is finally complete.',
#  'my longest streak consists of itself.',
#  'stupid internet isnt working on a project that builds with your pocket',
#  'but he also lives people who left before I went with the terrorists?',
#  'Then again, why are we still on my side of my team members or not, I am.',
#  'it was very interesting, I miss your hours! I move away',
#  'A judge banged the back of her, and shared to begin with. And hung up',
#  'Are you a Paris Hilton fan out of the water melon?',
#  'Hmmmm.... I blame it on Attila. To make sure not me.',
#  'WHY ARE NOT ALLOW TO CLAIM YOUR ARGUMENT IS OUT GUYS THIS SHOULD NEVER LAUGH BECAUSE YOU NEVER HAPPEN',
#  'lol patricia we throw money laundering training lol',
#  'So you logged in as I was simultaneously watching the show',
#  'So I apparently slipped and get on an adult',
#  'too much time in Mali',
#  'weird things going into a documentary on a thermometer.',
#  'we hired hitmen via remote desktop screen',
#  'yeah Kevin, I believe you play it after work externally',
#  'I was just looking for the scroll bar, so mad on Monday',
#  'I have noooo clue what happened, because the deadline is a sign',
#  'for some reason I thought there is no tomorrow',
#  'I no longer have more champagne',
#  'well I am sorry I was working for you Kevin?',
#  'Yea I still think my girlfriend had a clone but it does sound liq, laughing inside',
#  'I was relieved of pianos',
#  'I have been freed from la maison du chocolat?',
#  'next time they sell steaks for paper comment on it lol. I saw a guy who was sky diving with coffee, the interview goes down, another one',
#  'Denmark has been cancelled abruptly today!',
#  'he describes the word itself, thus, humoristicaly missing the world!',
#  'we all got one of the most annoying feelings ever. im pretty',
#  'i kind of get the universe of the email and drink too late?',
#  'My team was tired of forgetting it',
#  'somebody just need to cuddle together in BP',
#  'for those who use static subscription to run my cat would have it set up similarly I can remember how to turnover static cps subscriptions?',
#  'I went to herd cats',
#  'Mr. Daffron is not complete, long-term effects not Long ahahah',
#  'Yay! My team is having a candlelight vigil on Saturday night, hence the lack of rennovations.',
#  'I have to touch me which was really exotic here',
#  'AndyEmond This is why Yugoslavia failed to get their first language section',
#  'may doze off. that might ultimately backfire on monday',
#  'but never been urging army people to give me a perfect text-book',
#  'You cannot even realize that I joined a lot of prawns in a couple of weeks',
#  'We also have another nonlethal way in iconf, but eclipse doesnt work now?',
#  'I only want to keep explaining it to him now.']

# %%
markovHistory
# Out:
#     attachments     bot_id                                              icons  \
# 0           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 1           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 2           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 3           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 4           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 5           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 6           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 7           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 8           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 9           NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 10          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 11          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 12          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 13          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 14          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 15          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 16          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 17          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 18          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 19          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 20          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 21          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 22          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 23          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 24          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 25          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 26          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 27          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 28          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# 29          NaN  B29414C1J  {u'image_64': u'https://a.slack-edge.com/d4bf/...
# ..          ...        ...                                                ...
# 646         NaN        NaN                                                NaN
# 647         NaN        NaN                                                NaN
# 648         NaN        NaN                                                NaN
# 649         NaN        NaN                                                NaN
# 650         NaN        NaN                                                NaN
# 651         NaN        NaN                                                NaN
# 652         NaN        NaN                                                NaN
# 653         NaN        NaN                                                NaN
# 654         NaN        NaN                                                NaN
# 655         NaN        NaN                                                NaN
# 656         NaN        NaN                                                NaN
# 657         NaN        NaN                                                NaN
# 658         NaN        NaN                                                NaN
# 659         NaN        NaN                                                NaN
# 660         NaN        NaN                                                NaN
# 661         NaN        NaN                                                NaN
# 662         NaN        NaN                                                NaN
# 663         NaN        NaN                                                NaN
# 664         NaN        NaN                                                NaN
# 665         NaN        NaN                                                NaN
# 666         NaN        NaN                                                NaN
# 667         NaN        NaN                                                NaN
# 668         NaN        NaN                                                NaN
# 669         NaN        NaN                                                NaN
# 670         NaN        NaN                                                NaN
# 671         NaN        NaN                                                NaN
# 672         NaN        NaN                                                NaN
# 673         NaN        NaN                                                NaN
# 674         NaN        NaN                                                NaN
# 675         NaN        NaN                                                NaN
#
#        inviter purpose reactions          subtype  \
# 0          NaN     NaN       NaN      bot_message
# 1          NaN     NaN       NaN      bot_message
# 2          NaN     NaN       NaN      bot_message
# 3          NaN     NaN       NaN      bot_message
# 4          NaN     NaN       NaN      bot_message
# 5          NaN     NaN       NaN      bot_message
# 6          NaN     NaN       NaN      bot_message
# 7          NaN     NaN       NaN      bot_message
# 8          NaN     NaN       NaN      bot_message
# 9          NaN     NaN       NaN      bot_message
# 10         NaN     NaN       NaN      bot_message
# 11         NaN     NaN       NaN      bot_message
# 12         NaN     NaN       NaN      bot_message
# 13         NaN     NaN       NaN      bot_message
# 14         NaN     NaN       NaN      bot_message
# 15         NaN     NaN       NaN      bot_message
# 16         NaN     NaN       NaN      bot_message
# 17         NaN     NaN       NaN      bot_message
# 18         NaN     NaN       NaN      bot_message
# 19         NaN     NaN       NaN      bot_message
# 20         NaN     NaN       NaN      bot_message
# 21         NaN     NaN       NaN      bot_message
# 22         NaN     NaN       NaN      bot_message
# 23         NaN     NaN       NaN      bot_message
# 24         NaN     NaN       NaN      bot_message
# 25         NaN     NaN       NaN      bot_message
# 26         NaN     NaN       NaN      bot_message
# 27         NaN     NaN       NaN      bot_message
# 28         NaN     NaN       NaN      bot_message
# 29         NaN     NaN       NaN      bot_message
# ..         ...     ...       ...              ...
# 646  U28BV62LE     NaN       NaN     channel_join
# 647  U28BV62LE     NaN       NaN     channel_join
# 648  U28BV62LE     NaN       NaN     channel_join
# 649  U28BV62LE     NaN       NaN     channel_join
# 650        NaN     NaN       NaN              NaN
# 651        NaN     NaN       NaN              NaN
# 652        NaN     NaN       NaN              NaN
# 653        NaN     NaN       NaN              NaN
# 654        NaN     NaN       NaN              NaN
# 655        NaN     NaN       NaN              NaN
# 656        NaN     NaN       NaN              NaN
# 657        NaN     NaN       NaN              NaN
# 658        NaN     NaN       NaN              NaN
# 659        NaN     NaN       NaN              NaN
# 660        NaN     NaN       NaN              NaN
# 661        NaN     NaN       NaN              NaN
# 662        NaN     NaN       NaN              NaN
# 663        NaN     NaN       NaN              NaN
# 664        NaN     NaN       NaN     channel_join
# 665        NaN     NaN       NaN              NaN
# 666        NaN     NaN       NaN              NaN
# 667        NaN     NaN       NaN              NaN
# 668        NaN     NaN       NaN              NaN
# 669        NaN     NaN       NaN              NaN
# 670        NaN     NaN       NaN              NaN
# 671        NaN     NaN       NaN              NaN
# 672        NaN     NaN       NaN              NaN
# 673        NaN     NaN       NaN              NaN
# 674        NaN  markov       NaN  channel_purpose
# 675        NaN     NaN       NaN     channel_join
#
#                                                   text topic  \
# 0    everything else was supposed to finish moving ...   NaN
# 1             I wrestled against separation on sudoku.   NaN
# 2    Or maybe when I was an intern. She gave him cr...   NaN
# 3                too much Ashley Madison was a mistake   NaN
# 4                 must fight a Monday morning everyone   NaN
# 5    I prefer to ask pretty girl I watched the demo...   NaN
# 6    I know the prerequisites, Kevin, for me even t...   NaN
# 7    seriously!!!! washington heights was an articl...   NaN
# 8    the BP office is not for living creatures to m...   NaN
# 9    the hopeless underdogs are in front of him, in...   NaN
# 10   they arrived late and do you deserve all those...   NaN
# 11                     damn, im so much over the walls   NaN
# 12                         The European Union has gone   NaN
# 13     oh my god there a dominican republic of others.   NaN
# 14                 groupchat is actually becoming bald   NaN
# 15   for everyone who thinks football makes it look...   NaN
# 16   so one of my vps tells me, I already caught a ...   NaN
# 17   but my pokemons will be popular enought and th...   NaN
# 18   that awkward moment when you crash because of ...   NaN
# 19   A guy will no longer have to stop creating gro...   NaN
# 20   I also thought it might not end until you retu...   NaN
# 21   OR THERE WILL BE WINNING THIS MOVIE BETTER BE ...   NaN
# 22   Since I skipped lunch, so wrong, for a week; t...   NaN
# 23   Yeah, we are talking about your job and water ...   NaN
# 24   heck, friday is just in time every Monday, whe...   NaN
# 25   should keep going upwards, seems like a byte o...   NaN
# 26    like really? crap out of love this past weekend?   NaN
# 27         man saw him yesterday with various stomachs   NaN
# 28   so he self published it after the email and Ak...   NaN
# 29   the cute one got a lifelong worldwide ban from...   NaN
# ..                                                 ...   ...
# 646     <@U283YH4FN|rosegaelle> has joined the channel   NaN
# 647      <@U2856JBTN|mikespeti> has joined the channel   NaN
# 648      <@U28CB4D63|pattinska> has joined the channel   NaN
# 649       <@U28549XTL|hai.long> has joined the channel   NaN
# 650       AndyEmond     GO IN A UNIVERSE WHERE ROY IS!   NaN
# 651  AndyEmond     damn it Attila, Attila is still ...   NaN
# 652  *AndyEmond     Can’t wait to hear Sanjay is ra...   NaN
# 653  AndyEmond     So it’s because I’m always resiz...   NaN
# 654  AndyEmond     I speak hebrew there to steal yo...   NaN
# 655  AndyEmond     wow, the voice recognition, and ...   NaN
# 656  AndyEmond     Dude stop using only «next, next...   NaN
# 657  CarlaMorawicz     lol Andy gets grumpy when da...   NaN
# 658  CarlaMorawicz     that teaser was insane in th...   NaN
# 659  CarlaMorawicz     i see somebody’s been to ike...   NaN
# 660                                               cool   NaN
# 661                                               yeah   NaN
# 662               is this trained on the morgan chats?   NaN
# 663                                             hahaha   NaN
# 664            <@U284CPXM4|roy> has joined the channel   NaN
# 665   AndyEmond     WE WILL GIVE THEM THE LAUNDRY!!!!1   NaN
# 666  AndyEmond     I should randomly poke to contai...   NaN
# 667  AndyEmond     wait, she connects, she’ll be re...   NaN
# 668  AndyEmond     I like how creative you still ca...   NaN
# 669  AndyEmond     Kevin still hangs around during ...   NaN
# 670  AndyEmond     I don’t see why we are all going...   NaN
# 671  AndyEmond     are you sure that’s why I enjoy ...   NaN
# 672  AndyEmond     who’s ready to go back home to a...   NaN
# 673  AndyEmond     you get me to live with artifici...   NaN
# 674  <@U28BV62LE|sunkev> set the channel purpose: m...   NaN
# 675         <@U28BV62LE|sunkev> has joined the channel   NaN
#
#                     ts     type       user          username
# 0    1474045693.000102  message        NaN      Markov Kevin
# 1    1474045392.000101  message        NaN     Markov Attila
# 2    1474045090.000100  message        NaN        Markov R-G
# 3    1474044788.000099  message        NaN      Markov Kevin
# 4    1474044487.000098  message        NaN    Markov Amilcar
# 5    1474044185.000097  message        NaN  Markov Alexandre
# 6    1474043884.000096  message        NaN     Markov Attila
# 7    1474043582.000095  message        NaN    Markov Amilcar
# 8    1474043282.000094  message        NaN     Markov Attila
# 9    1474042981.000093  message        NaN      Markov Kevin
# 10   1474042680.000092  message        NaN     Markov Attila
# 11   1474042378.000091  message        NaN   Markov Hai-Long
# 12   1474042076.000090  message        NaN     Markov Attila
# 13   1474041775.000089  message        NaN      Markov Kevin
# 14   1474041474.000088  message        NaN       Markov Andy
# 15   1474041173.000087  message        NaN      Markov Kevin
# 16   1474040871.000086  message        NaN    Markov Amilcar
# 17   1474040571.000085  message        NaN       Markov Andy
# 18   1474040271.000084  message        NaN      Markov Kevin
# 19   1474039970.000083  message        NaN       Markov Andy
# 20   1474039669.000082  message        NaN        Markov R-G
# 21   1474039368.000081  message        NaN       Markov Andy
# 22   1474039067.000080  message        NaN        Markov R-G
# 23   1474038765.000079  message        NaN      Markov Kevin
# 24   1474038464.000078  message        NaN     Markov Attila
# 25   1474038163.000077  message        NaN     Markov Attila
# 26   1474037862.000076  message        NaN    Markov Amilcar
# 27   1474037561.000075  message        NaN      Markov Kevin
# 28   1474037260.000074  message        NaN        Markov Roy
# 29   1474036958.000073  message        NaN      Markov Kevin
# ..                 ...      ...        ...               ...
# 646  1473193744.000029  message  U283YH4FN               NaN
# 647  1473193743.000028  message  U2856JBTN               NaN
# 648  1473193743.000027  message  U28CB4D63               NaN
# 649  1473193743.000026  message  U28549XTL               NaN
# 650  1473192656.000025  message  U28BV62LE               NaN
# 651  1473192632.000024  message  U28BV62LE               NaN
# 652  1473192607.000023  message  U28BV62LE               NaN
# 653  1473192581.000022  message  U28BV62LE               NaN
# 654  1473192518.000021  message  U28BV62LE               NaN
# 655  1473192470.000020  message  U28BV62LE               NaN
# 656  1473192429.000019  message  U28BV62LE               NaN
# 657  1473192304.000018  message  U28BV62LE               NaN
# 658  1473192236.000017  message  U28BV62LE               NaN
# 659  1473192162.000016  message  U28BV62LE               NaN
# 660  1473180286.000015  message  U284CPXM4               NaN
# 661  1473180278.000014  message  U28BV62LE               NaN
# 662  1473180128.000013  message  U284CPXM4               NaN
# 663  1473180097.000012  message  U284CPXM4               NaN
# 664  1473180092.000011  message  U284CPXM4               NaN
# 665  1473180051.000010  message  U28BV62LE               NaN
# 666  1473180028.000009  message  U28BV62LE               NaN
# 667  1473179980.000008  message  U28BV62LE               NaN
# 668  1473179957.000007  message  U28BV62LE               NaN
# 669  1473179882.000006  message  U28BV62LE               NaN
# 670  1473179862.000005  message  U28BV62LE               NaN
# 671  1473179832.000004  message  U28BV62LE               NaN
# 672  1473179718.000003  message  U28BV62LE               NaN
# 673  1473179659.000002  message  U28BV62LE               NaN
# 674  1473134117.000003  message  U28BV62LE               NaN
# 675  1473134117.000002  message  U28BV62LE               NaN
#
# [676 rows x 13 columns]

# %%
growMarkov()
# Out:
# $$$
# my
# manager
# saw
# that
# guy
# after
# their
# phone
# on
# Hispanic
# Heritage
# Month.
# u'my manager saw that guy after their phone on Hispanic Heritage Month.'

# %%
(lambda t:random.choice([v for s in [[x]*t[x] for x in t.index] for v in s]))(pd.Series(markovmap['$$$'][1]))
# Out:
# u'so'

# %%
generalHistory
# Out:
#                                            attachments     bot_id  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# 5                                                  NaN        NaN
# 6                                                  NaN        NaN
# 7                                                  NaN        NaN
# 8                                                  NaN        NaN
# 9                                                  NaN        NaN
# 10                                                 NaN        NaN
# 11   [{u'image_bytes': 24875, u'image_width': 256, ...        NaN
# 12                                                 NaN        NaN
# 13                                                 NaN        NaN
# 14                                                 NaN        NaN
# 15                                                 NaN        NaN
# 16                                                 NaN        NaN
# 17                                                 NaN        NaN
# 18                                                 NaN        NaN
# 19                                                 NaN        NaN
# 20                                                 NaN        NaN
# 21                                                 NaN        NaN
# 22                                                 NaN        NaN
# 23                                                 NaN        NaN
# 24                                                 NaN        NaN
# 25                                                 NaN        NaN
# 26                                                 NaN       None
# 27                                                 NaN        NaN
# 28                                                 NaN        NaN
# 477     <@U283YH4FN|rosegaelle> has joined the channel  1472997472.126664
#
#         type upload       user              username
# 0    message    NaN  U285RLCGG                   NaN
# 1    message    NaN  U2A14FD9B                   NaN
# 2    message    NaN  U2A14FD9B                   NaN
# 3    message    NaN  U2A14FD9B                   NaN
# 4    message    NaN  U28BV62LE                   NaN
# 5    message    NaN  U28BV62LE                   NaN
# 6    message    NaN  U28BV62LE                   NaN
# 7    message    NaN  U285RLCGG                   NaN
# 8    message    NaN  U285RLCGG                   NaN
# 9    message    NaN  U28BV62LE                   NaN
# 10   message    NaN  U28BV62LE                   NaN
# 11   message    NaN  U28BV62LE                   NaN
# 12   message    NaN  USLACKBOT                   NaN
# 13   message    NaN  U290ASU2G                   NaN
# 14   message    NaN  U290ASU2G                   NaN
# 15   message    NaN  USLACKBOT                   NaN
# 16   message    NaN  U28BV62LE                   NaN
# 17   message    NaN  USLACKBOT                   NaN
# 18   message    NaN  U28BV62LE                   NaN
# 19   message    NaN  USLACKBOT                   NaN
# 20   message    NaN  U28BV62LE                   NaN
# 21   message    NaN  USLACKBOT                   NaN
# 22   message    NaN  U28BV62LE                   NaN
# 23   message    NaN  USLACKBOT                   NaN
# 24   message    NaN  U28BV62LE                   NaN
# 25   message    NaN  U28BV62LE                   NaN
# 26   message   True  U290ASU2G  <@U290ASU2G|attilab>
# 27   message    NaN  U28BV62LE                   NaN
# 28   message    NaN  U28BV62LE                   NaN
# 29   message    NaN  U290ASU2G                   NaN
# ..       ...    ...        ...                   ...
# 448  message    NaN  U284CPXM4                   NaN
# 449  message    NaN  U28BV62LE                   NaN
# 450  message    NaN  U28BV62LE                   NaN
# 451  message    NaN        NaN        Steve Lieblich
# 452  message    NaN        NaN          James Gorman
# 453  message    NaN        NaN        Steve Lieblich
# 454  message    NaN  U284CPXM4                   NaN
# 455  message    NaN  U284CPXM4                   NaN
# 456  message    NaN  U28BV62LE                   NaN
# 457  message    NaN  U28BV62LE                   NaN
# 458  message    NaN  U28DY23AL                   NaN
# 459  message    NaN  U28DY23AL                   NaN
# 460  message    NaN  U284CPXM4                   NaN
# 461  message    NaN  U284CPXM4                   NaN
# 462  message    NaN  U285RLCGG                   NaN
# 463  message    NaN  U285RLCGG                   NaN
# 464  message    NaN  U285RLCGG                   NaN
# 465  message    NaN  U28CB4D63                   NaN
# 466  message    NaN  U28BV62LE                   NaN
# 467  message    NaN  U28BV62LE                   NaN
# 468  message    NaN  U28BV62LE                   NaN
# 469  message    NaN  U28BV62LE                   NaN
# 470  message    NaN  U285RLCGG                   NaN
# 471  message    NaN  U285RLCGG                   NaN
# 472  message    NaN  U2856JBTN                   NaN
# 473  message    NaN  U28549XTL                   NaN
# 474  message    NaN  U28549XTL                   NaN
# 475  message    NaN  U284CPXM4                   NaN
# 476  message    NaN  U283YH4FN                   NaN
# 477  message    NaN  U283YH4FN                   NaN
#
# [478 rows x 14 columns]
