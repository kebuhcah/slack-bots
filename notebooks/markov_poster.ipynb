# %%
import json
import urllib2
import pandas as pd
import time

lieblichUrl='https://hooks.slack.com/services/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'
markovUrl='https://hooks.slack.com/services/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'

def slackPost(text,username=None, icon_emoji=None, channel='#random', url=markovUrl):
    data = {
        'username': username,
        'icon_emoji': icon_emoji,
        'channel': channel,
        'text': text
    }

    req = urllib2.Request(url)
    req.add_header('Content-Type', 'application/json')

    response = urllib2.urlopen(req, json.dumps(data))
    
    print response
    
content=pd.read_csv("markov_content.csv",delimiter="|")
content.columns=content.columns.str.strip()
content['user']=content['user'].str.strip()
content['message']=content['message'].str.strip()

user_emoji_map = {
    'Attila' : ':skull:',
    'Carla' : ':smiley_cat:',
    'Amilcar' : ':sleeping:',
    'R-G' : ':upside_down_face:',
    'Andy' : ':hand:',
    'Roy' : ':thinking_face:',
    'David' : ':smiling_imp:',
    'Akira' : ':japanese_goblin:',
    'Nanfei' : ':bird:',
    'Shelley' : ':shell:',
    'Jinnie' : ':dog2:',
    'Hai-Long' : ':dragon:',
    'Gabor' : ':sheep:',
    'Dusan' : ':stuck_out_tongue_winking_eye:',
    'Derek' : ':neutral_face:',
    'Huy Quang' : ':flashlight:',
    'Ivett' : ':cocktail:',
    'Anand' : ':boy::skin-tone-5:',
    'Kevin' : ':fire:',
    'Szabolcs' : ':crossed_swords:',
    'Lorant' : ':beer:',    
    'Alexandre' : ':robot_face:',    
    'Devin' : ':alien:',    
    'Vaibhav' : ':wheel_of_dharma:',    
}

# %%
slackPost('morning',channel='#general',url=lieblichUrl)
# Out:
# <addinfourl at 4395603944 whose fp = <socket._fileobject object at 0x105fd7750>>

# %%
for i in range(0,len(content)):
    user = content.ix[i]['user']
    message = content.ix[i]['message']
    print user, message
    #slackPost(message, 'Markov ' + user, user_emoji_map[user], '#markov')
    #time.sleep(30)
# Out:
# Kevin there was pizza lunch appointment for the day. Going to upgrade from markovian post makes the story much darker
# Amilcar marvel has a thing between the method that was me yesterday at the olympics with sweets
# Hai-Long oh awesome... there is no way to have a question.
# Amilcar I can pass by and one of my pokemon is reacting to game
# Attila In the weirdest schedule, fridays tend to get a third for example
# Andy who knows how to use the martian exemple?
# Kevin you should do it in the future - acquired immune deficiency syndrome well after ignoring my irrational fears.
# Amilcar you can use this as my actual razor, which is bs
# Kevin i like the solemn funerals elsewhere
# R-G OH NO! WHAT HAPPENED IN GROUPCHAT AND his first opera? I finally think I cared to worry about Vine?
# Alexandre Wish I could check the speed of light
# R-G Why would anyone wants to greet the lunch-turnover option...
# Andy I was talking about something out of context I guess the Russians speak with humans?
# Amilcar I found a giant LOL at my desk so he can meet ppl
# Attila when the chinese government tries to sell it has to shoot me now, please.
# Alexandre raving is an awesome idea
# Attila three cheers for living without any issues
# R-G You are not aware of the business card exchange component?
# Attila my vision of Rose totally messed up my whole unix env
# Roy i speak her language now i understand the hype
# Devin The font police, their inside of them have gaz, its funny
# Amilcar AND YOU HAD MY IDEA!!! LOOKING AT ME WITH THE CROSS!
# R-G My entire teams resigned.
# Kevin Scottish flag proudly floating directly into the microwave
# Alexandre Sanjay? he should put them into cooking, you say that in english
# Dusan too many health benefits from the cgi-bin folder
# David this harrassment will have a nice surprise
# Amilcar lmaoooo at inner lambda functions and friday lol
# Kevin what the heck my shirt broke
# R-G Do you guys know anything about understanding women. Most likely thanks for checking out of my head again!!!
# Hai-Long oh, i was going to suggest a good actor... but apparently not.
# Amilcar yea the real world is the best!!!
# Attila man, I wish I had an extremely boring meeting with a cake on winxp and now
# Vaibhav where were my visa soon.. will plan to apply for the perfect art
# Kevin Can you run by the Turks, and be like KTHXBYE
# David the steel ball is pushing for things from buzzfeed
# Kevin You can go whenever anyone tried to recruit me if the recovery is what comes online.
# Carla MarkDavid is soo happy to eat Noodles
# Kevin interesting geopolitical analysis of embarassement..
# Amilcar these things suck if they gave me a script to automate the creation of it but I think the pikachu is like ... yea lol
# Kevin Dude stop having such a terrible friend.
# Amilcar my girlfriend brought some in today. so we ran on my phone on the approval system
# Kevin LOLOLOLOL FAIL LOL I like these offensive images.
# Attila I even wondered how much he is saying hello
# Andy ahh these people did this head-blowing gif when the browser is still ahead
# R-G Oh boy, I have maintained the Philippines????
# Kevin yeah, this is a reused joke, but a lot more intense.
# R-G Btw Andy, you forgot to add to my favourite broadcast station in Astoria?
# Kevin RGBelinga That awkward moment when your regression team is interested in my yoghurt container
# Attila ah, I almost pissed myself watching the graduation ceremony?
# Kevin pardon the microwave... thanks for the summer olympics

# %%
content['user'].apply(lambda x: user_emoji_map[x])
# Out:
# 0                             :fire:
# 1                         :sleeping:
# 2                           :dragon:
# 3                         :sleeping:
# 4                            :skull:
# 5                             :hand:
# 6                             :fire:
# 7                         :sleeping:
# 8                             :fire:
# 9                 :upside_down_face:
# 10                      :robot_face:
# 11                :upside_down_face:
# 12                            :hand:
# 13                        :sleeping:
# 14                           :skull:
# 15                      :robot_face:
# 16                           :skull:
# 17                :upside_down_face:
# 18                           :skull:
# 19                   :thinking_face:
# 20                           :alien:
# 21                        :sleeping:
# 22                :upside_down_face:
# 23                            :fire:
# 24                      :robot_face:
# 25    :stuck_out_tongue_winking_eye:
# 26                     :smiling_imp:
# 27                        :sleeping:
# 28                            :fire:
# 29                :upside_down_face:
# 30                          :dragon:
# 31                        :sleeping:
# 32                           :skull:
# 33                 :wheel_of_dharma:
# 34                            :fire:
# 35                     :smiling_imp:
# 36                            :fire:
# 37                      :smiley_cat:
# 38                            :fire:
# 39                        :sleeping:
# 40                            :fire:
# 41                        :sleeping:
# 42                            :fire:
# 43                           :skull:
# 44                            :hand:
# 45                :upside_down_face:
# 46                            :fire:
# 47                :upside_down_face:
# 48                            :fire:
# 49                           :skull:
# 50                            :fire:
# Name: user, dtype: object

# %%
content
# Out:
#          user                                            message
# 0       Kevin  there was pizza lunch appointment for the day....
# 1     Amilcar  marvel has a thing between the method that was...
# 2    Hai-Long  oh awesome... there is no way to have a question.
# 3     Amilcar  I can pass by and one of my pokemon is reactin...
# 4      Attila  In the weirdest schedule, fridays tend to get ...
# 5        Andy          who knows how to use the martian exemple?
# 6       Kevin  you should do it in the future - acquired immu...
# 7     Amilcar   you can use this as my actual razor, which is bs
# 8       Kevin               i like the solemn funerals elsewhere
# 9         R-G  OH NO! WHAT HAPPENED IN GROUPCHAT AND his firs...
# 10  Alexandre              Wish I could check the speed of light
# 11        R-G  Why would anyone wants to greet the lunch-turn...
# 12       Andy  I was talking about something out of context I...
# 13    Amilcar  I found a giant LOL at my desk so he can meet ppl
# 14     Attila  when the chinese government tries to sell it h...
# 15  Alexandre                          raving is an awesome idea
# 16     Attila         three cheers for living without any issues
# 17        R-G  You are not aware of the business card exchang...
# 18     Attila  my vision of Rose totally messed up my whole u...
# 19        Roy     i speak her language now i understand the hype
# 20      Devin  The font police, their inside of them have gaz...
# 21    Amilcar  AND YOU HAD MY IDEA!!! LOOKING AT ME WITH THE ...
# 22        R-G                          My entire teams resigned.
# 23      Kevin  Scottish flag proudly floating directly into t...
# 24  Alexandre  Sanjay? he should put them into cooking, you s...
# 25      Dusan   too many health benefits from the cgi-bin folder
# 26      David         this harrassment will have a nice surprise
# 27    Amilcar   lmaoooo at inner lambda functions and friday lol
# 28      Kevin                       what the heck my shirt broke
# 29        R-G  Do you guys know anything about understanding ...
# 30   Hai-Long  oh, i was going to suggest a good actor... but...
# 31    Amilcar                  yea the real world is the best!!!
# 32     Attila  man, I wish I had an extremely boring meeting ...
# 33    Vaibhav  where were my visa soon.. will plan to apply f...
# 34      Kevin      Can you run by the Turks, and be like KTHXBYE
# 35      David  the steel ball is pushing for things from buzz...
# 36      Kevin  You can go whenever anyone tried to recruit me...
# 37      Carla              MarkDavid is soo happy to eat Noodles
# 38      Kevin  interesting geopolitical analysis of embarasse...
# 39    Amilcar  these things suck if they gave me a script to ...
# 40      Kevin           Dude stop having such a terrible friend.
# 41    Amilcar  my girlfriend brought some in today. so we ran...
# 42      Kevin  LOLOLOLOL FAIL LOL I like these offensive images.
# 43     Attila        I even wondered how much he is saying hello
# 44       Andy  ahh these people did this head-blowing gif whe...
# 45        R-G      Oh boy, I have maintained the Philippines????
# 46      Kevin  yeah, this is a reused joke, but a lot more in...
# 47        R-G  Btw Andy, you forgot to add to my favourite br...
# 48      Kevin  RGBelinga That awkward moment when your regres...
# 49     Attila  ah, I almost pissed myself watching the gradua...
# 50      Kevin  pardon the microwave... thanks for the summer ...
