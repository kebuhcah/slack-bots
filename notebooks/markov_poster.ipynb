# %%
import json
import urllib2
import pandas as pd
import time

lieblichUrl='https://hooks.slack.com/services/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'
markovUrl='https://hooks.slack.com/services/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'

def slackPost(text,username=None, icon_emoji=None, channel='#random', url=markovUrl):
    data = {
        'username': username,
        'icon_emoji': icon_emoji,
        'channel': channel,
        'text': text
    }

    req = urllib2.Request(url)
    req.add_header('Content-Type', 'application/json')

    response = urllib2.urlopen(req, json.dumps(data))
    
    print response
    
content=pd.read_csv("markov_content.csv",delimiter="|")
content.columns=content.columns.str.strip()
content['user']=content['user'].str.strip()
content['message']=content['message'].str.strip()

user_emoji_map = {
    'Attila' : ':skull:',
    'Carla' : ':smiley_cat:',
    'Amilcar' : ':sleeping:',
    'R-G' : ':upside_down_face:',
    'Andy' : ':hand:',
    'Roy' : ':thinking_face:',
    'David' : ':smiling_imp:',
    'Akira' : ':japanese_goblin:',
    'Nanfei' : ':bird:',
    'Shelley' : ':shell:',
    'Jinnie' : ':dog2:',
    'Hai-Long' : ':dragon:',
    'Gabor' : ':sheep:',
    'Dusan' : ':stuck_out_tongue_winking_eye:',
    'Derek' : ':neutral_face:',
    'Huy Quang' : ':flashlight:',
    'Ivett' : ':cocktail:',
    'Anand' : ':boy::skin-tone-5:',
    'Kevin' : ':fire:',
    'Szabolcs' : ':crossed_swords:',
}

# %%
slackPost('Ouaouh',channel='#general',url=lieblichUrl)
# Out:
# <addinfourl at 4396073328 whose fp = <socket._fileobject object at 0x10602a850>>

# %%
for i in range(0,len(content)):
    user = content.ix[i]['user']
    message = content.ix[i]['message']
    print user, message
    #slackPost(message, 'Markov ' + user, user_emoji_map[user], '#markov')
    #time.sleep(30)
# Out:
# Nanfei amilcar. my machine today was some rather healthy braised fish.
# R-G Guess what? There is a Pokemon Go for it!
# Amilcar i dont see how V-day can do service to parse an hour
# R-G You are just trying to get rid of the floor!
# Attila flood-resistant mirrordrilling machine in this, because asia might just be a rumour
# Amilcar the one with the kid soldiers fighting machine for a short film, had halal cart
# R-G A few hours and I need a life again. Create a friend for the duel.
# R-G I am considering tinkering with you. I are the best Attila!
# Attila I am not sure if I should move to live on and I had to do that frequently used to.
# Huy Quang Ivett knows more about the usuall bs?
# Kevin holy shit I forgot to eat your resume?
# Roy did you guys see the meaning in the email was that an outage though?
# Kevin I have the add-in because it is not visible behind the clouds
# R-G Good think we refer to blood for a divorce...
# Jinnie does anyone know a male name which is jingwen
# R-G I am not a fan of politics, but not cakes
# Kevin I was on fire yesterday I gave up trying to release link.
# Carla i wanna witness the lost chocolate milk?
# Roy your whole floor would be funny if you delete your distribution group chat
# R-G I get it a lot in front of the room, notice that my logic is an insult to take the Metro North. Train CLI, not implying anything, lest I resume my batch!
# Kevin my markovbot how is that even possible, in the non-Markov rooms...
# Nanfei remind me to go focus on going to seoul, I think of tokyo
# Kevin your dude was standing behind me again
# Andy I think they show you the pond?
# R-G I strongly argue against black squares
# Hai-Long pursue masters in internet explorer everytime I used scala
# Carla it was basically a great Jesus is anybody fooding today?!?
# Amilcar i got my brother into the microwave

# %%
content['user'].apply(lambda x: user_emoji_map[x])
# Out:
# 0                 :bird:
# 1     :upside_down_face:
# 2             :sleeping:
# 3     :upside_down_face:
# 4                :skull:
# 5             :sleeping:
# 6     :upside_down_face:
# 7     :upside_down_face:
# 8                :skull:
# 9           :flashlight:
# 10                :fire:
# 11       :thinking_face:
# 12                :fire:
# 13    :upside_down_face:
# 14                :dog2:
# 15    :upside_down_face:
# 16                :fire:
# 17          :smiley_cat:
# 18       :thinking_face:
# 19    :upside_down_face:
# 20                :fire:
# 21                :bird:
# 22                :fire:
# 23                :hand:
# 24    :upside_down_face:
# 25              :dragon:
# 26          :smiley_cat:
# 27            :sleeping:
# Name: user, dtype: object

# %%
content
# Out:
#          user                                            message
# 0      Nanfei  amilcar. my machine today was some rather heal...
# 1         R-G          Guess what? There is a Pokemon Go for it!
# 2     Amilcar  i dont see how V-day can do service to parse a...
# 3         R-G       You are just trying to get rid of the floor!
# 4      Attila  flood-resistant mirrordrilling machine in this...
# 5     Amilcar  the one with the kid soldiers fighting machine...
# 6         R-G  A few hours and I need a life again. Create a ...
# 7         R-G  I am considering tinkering with you. I are the...
# 8      Attila  I am not sure if I should move to live on and ...
# 9   Huy Quang              Ivett knows more about the usuall bs?
# 10      Kevin             holy shit I forgot to eat your resume?
# 11        Roy  did you guys see the meaning in the email was ...
# 12      Kevin  I have the add-in because it is not visible be...
# 13        R-G      Good think we refer to blood for a divorce...
# 14     Jinnie      does anyone know a male name which is jingwen
# 15        R-G          I am not a fan of politics, but not cakes
# 16      Kevin  I was on fire yesterday I gave up trying to re...
# 17      Carla           i wanna witness the lost chocolate milk?
# 18        Roy  your whole floor would be funny if you delete ...
# 19        R-G  I get it a lot in front of the room, notice th...
# 20      Kevin  my markovbot how is that even possible, in the...
# 21     Nanfei  remind me to go focus on going to seoul, I thi...
# 22      Kevin             your dude was standing behind me again
# 23       Andy                    I think they show you the pond?
# 24        R-G             I strongly argue against black squares
# 25   Hai-Long  pursue masters in internet explorer everytime ...
# 26      Carla  it was basically a great Jesus is anybody food...
# 27    Amilcar                i got my brother into the microwave
