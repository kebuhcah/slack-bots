# %%
import json
import urllib2
import pandas as pd
import time

lieblichUrl='https://hooks.slack.com/services/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'
markovUrl='https://hooks.slack.com/services/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'

def slackPost(text,username=None, icon_emoji=None, channel='#random', url=markovUrl):
    data = {
        'username': username,
        'icon_emoji': icon_emoji,
        'channel': channel,
        'text': text
    }

    req = urllib2.Request(url)
    req.add_header('Content-Type', 'application/json')

    response = urllib2.urlopen(req, json.dumps(data))
    
    print response
    
content=pd.read_csv("markov_content.csv",delimiter="|")
content.columns=content.columns.str.strip()
content['user']=content['user'].str.strip()
content['message']=content['message'].str.strip()

user_emoji_map = {
    'Attila' : ':skull:',
    'Carla' : ':smiley_cat:',
    'Amilcar' : ':sleeping:',
    'R-G' : ':upside_down_face:',
    'Andy' : ':hand:',
    'Roy' : ':thinking_face:',
    'David' : ':smiling_imp:',
    'Akira' : ':japanese_goblin:',
    'Nanfei' : ':bird:',
    'Shelley' : ':shell:',
    'Jinnie' : ':dog2:',
    'Hai-Long' : ':dragon:',
    'Gabor' : ':sheep:',
    'Dusan' : ':stuck_out_tongue_winking_eye:',
    'Derek' : ':neutral_face:',
    'Huy Quang' : ':flashlight:',
    'Ivett' : ':cocktail:',
    'Anand' : ':boy::skin-tone-5:',
    'Kevin' : ':fire:',
    'Szabolcs' : ':crossed_swords:',
    'Lorant' : ':beer:',    
}

# %%
slackPost('Ouaouh',channel='#general',url=lieblichUrl)
# Out:
# <addinfourl at 4396073328 whose fp = <socket._fileobject object at 0x10602a850>>

# %%
for i in range(0,len(content)):
    user = content.ix[i]['user']
    message = content.ix[i]['message']
    print user, message
    #slackPost(message, 'Markov ' + user, user_emoji_map[user], '#markov')
    #time.sleep(30)
# Out:
# R-G Oh, je vienne durant les fautes, je rencontre Mr. Sun?
# Kevin I am not really singular, but they changed his passwords. The US Supreme Court has been a good idea?
# David An Egg is pretty far from soulless by design
# Kevin heatmap is gonna boop him. this dude needs to beat me
# R-G Is there a way to cleanup the language THE NOISE IS BACK
# Kevin lol I might have just changed the font of stray dogs
# Amilcar i think they need more dragons
# Attila certain someone from my team is having experience
# Andy but I have to say it might take this, could be code?
# Attila heads will be glad to dial in, wish I had the exact model
# Andy I AM NOT RECOGNIZE YOUR NEW KING GROUP CHAT
# David I am morbidly curious as if it will happen.. Contrast this is a thing on a screen
# Attila tomorrow I am still in the Golden Gate Bridge like these are not frequent either
# Ivett my manager saw that I have to send the Communism in the summer
# Kevin I saw someone will go to a sweedish house warming party at least
# R-G March is going to be rough this next year for example
# Hai-Long lool... Kevin... you know something will play on myself in your place?
# Kevin I am afraid to go straight, remember? I really liked the second coffee
# R-G I am really late because of the protests... Twelve deaths reported so different!
# Hai-Long does anyone know if we can eat together in danger!
# Andy I feellike Akira had to fight to get wireshark
# Hai-Long i have two weekends in the DRYER!!!!
# Carla my ego filter is spamming me!
# Roy i cant find my Android L update! how do you get the pun though?
# Carla NOOO! MarkCarla!!! NOT THE OLD PORT!!!!
# Kevin well why do whales explode?
# Attila pretty and you could have at all, there indeed is an end of day...
# Kevin I should continue the lowest above-average poster. and what do I find? intense
# Hai-Long well... sansa the actress is in danger!
# Kevin Strats have such a bad idea i was gonna kick you code
# Andy expansion team are expensive for making everything depressive
# Kevin Voldemort will face it, it becomes chrap whenever I visit the meth addict
# Amilcar I can give you the flu if anyone wants to go sky diving with some wildfire
# R-G I told them that their code would NOT interrupt me as a Java developer.
# Nanfei did Tokyo proud by supplying lower quality caffeine
# R-G Someone even more discouraged to send them almost any flowers on Skype next week.
# Andy I was talking about your job that you are fast.
# R-G Now, I am having trouble connecting to throw up guys?
# Kevin Thanks to Tanay, Krithika will be having such a roller coaster of wrestling policemen...
# David randomly stumbled on the floor? Interesting storage solution. This cancels out how to handle snow for patriotic woman football fans
# R-G I still cannot delete posts in our pantry.
# Carla im a bad guess im a bad person
# Kevin just randomly generated chat, for holy Christ
# Lorant please remove my name from me
# R-G Bosnia has been quiet today and they got lost in a movie, merchandise, etc.
# Nanfei oh wow, just noticed that I was trying to hint at the palce with my manager today...
# R-G I give you the name you can only be Amilcar - shortbread cookies, by next week. Beside, March is in the fridge???
# Kevin MY BODY IS WINNING AGAINST GERMANY
# R-G No more carrying two lovely ladies.
# Andy wow, being sponsored by your mother would have lead to the email
# Kevin My priest accidentally logged in yesterday
# Amilcar funny vine is a mess
# Attila she happens to be suspicious and I had all the traits of years back in my day, though.
# Kevin hmm i dont see emails to catch pokemon today?
# R-G I thought I had been confirmed? Some of these were WFH today then melting after all.
# Andy liek hockey but not in a restroom
# Kevin MARKOV IS RESUMING DIPLOMATIC RELATIONS WITH A DC COMIC
# Attila humorous lemur was obligatory for the non-polish speaky person
# Kevin Interestingly, I am really going live, remember? I am making him to do anything for a moment and ran up to date!
# Carla u get chunks of course!
# Roy just realized, my square is love?
# Kevin A stranger french-kissed your cheek
# Amilcar leave out of my queries. Do No Harm but my girlfriend had to configure my eclipse
# R-G Guess who is watching the procession with the blinds down... No big deal
# Akira oh i can keep on talking, then hitchhike to test everything out
# Andy oh shit I see your girlfriend at that point he will put the best moustache
# Kevin you put music from French Belgian Waffles in a story on line
# Andy I hope you never getting back from africa
# Kevin WHOA BEN CARSON IS GHOST NOW
# Lorant Sounds logical but not correct.
# Kevin hmm not quite, because Ecuador is a random hole in Finnish well.
# Attila I certainly not the best prey ever.
# Dusan hahahahaah nice kevin... your bot overload

# %%
content['user'].apply(lambda x: user_emoji_map[x])
# Out:
# 0                 :upside_down_face:
# 1                             :fire:
# 2                      :smiling_imp:
# 3                             :fire:
# 4                 :upside_down_face:
# 5                             :fire:
# 6                         :sleeping:
# 7                            :skull:
# 8                             :hand:
# 9                            :skull:
# 10                            :hand:
# 11                     :smiling_imp:
# 12                           :skull:
# 13                        :cocktail:
# 14                            :fire:
# 15                :upside_down_face:
# 16                          :dragon:
# 17                            :fire:
# 18                :upside_down_face:
# 19                          :dragon:
# 20                            :hand:
# 21                          :dragon:
# 22                      :smiley_cat:
# 23                   :thinking_face:
# 24                      :smiley_cat:
# 25                            :fire:
# 26                           :skull:
# 27                            :fire:
# 28                          :dragon:
# 29                            :fire:
#                    ...
# 43                            :beer:
# 44                :upside_down_face:
# 45                            :bird:
# 46                :upside_down_face:
# 47                            :fire:
# 48                :upside_down_face:
# 49                            :hand:
# 50                            :fire:
# 51                        :sleeping:
# 52                           :skull:
# 53                            :fire:
# 54                :upside_down_face:
# 55                            :hand:
# 56                            :fire:
# 57                           :skull:
# 58                            :fire:
# 59                      :smiley_cat:
# 60                   :thinking_face:
# 61                            :fire:
# 62                        :sleeping:
# 63                :upside_down_face:
# 64                 :japanese_goblin:
# 65                            :hand:
# 66                            :fire:
# 67                            :hand:
# 68                            :fire:
# 69                            :beer:
# 70                            :fire:
# 71                           :skull:
# 72    :stuck_out_tongue_winking_eye:
# Name: user, dtype: object

# %%
content
# Out:
#         user                                            message
# 0        R-G  Oh, je vienne durant les fautes, je rencontre ...
# 1      Kevin  I am not really singular, but they changed his...
# 2      David       An Egg is pretty far from soulless by design
# 3      Kevin  heatmap is gonna boop him. this dude needs to ...
# 4        R-G  Is there a way to cleanup the language THE NOI...
# 5      Kevin  lol I might have just changed the font of stra...
# 6    Amilcar                     i think they need more dragons
# 7     Attila  certain someone from my team is having experience
# 8       Andy  but I have to say it might take this, could be...
# 9     Attila  heads will be glad to dial in, wish I had the ...
# 10      Andy        I AM NOT RECOGNIZE YOUR NEW KING GROUP CHAT
# 11     David  I am morbidly curious as if it will happen.. C...
# 12    Attila  tomorrow I am still in the Golden Gate Bridge ...
# 13     Ivett  my manager saw that I have to send the Communi...
# 14     Kevin  I saw someone will go to a sweedish house warm...
# 15       R-G  March is going to be rough this next year for ...
# 16  Hai-Long  lool... Kevin... you know something will play ...
# 17     Kevin  I am afraid to go straight, remember? I really...
# 18       R-G  I am really late because of the protests... Tw...
# 19  Hai-Long  does anyone know if we can eat together in dan...
# 20      Andy     I feellike Akira had to fight to get wireshark
# 21  Hai-Long               i have two weekends in the DRYER!!!!
# 22     Carla                      my ego filter is spamming me!
# 23       Roy  i cant find my Android L update! how do you ge...
# 24     Carla            NOOO! MarkCarla!!! NOT THE OLD PORT!!!!
# 25     Kevin                        well why do whales explode?
# 26    Attila  pretty and you could have at all, there indeed...
# 27     Kevin  I should continue the lowest above-average pos...
# 28  Hai-Long            well... sansa the actress is in danger!
# 29     Kevin  Strats have such a bad idea i was gonna kick y...
# ..       ...                                                ...
# 43    Lorant                      please remove my name from me
# 44       R-G  Bosnia has been quiet today and they got lost ...
# 45    Nanfei  oh wow, just noticed that I was trying to hint...
# 46       R-G  I give you the name you can only be Amilcar - ...
# 47     Kevin                 MY BODY IS WINNING AGAINST GERMANY
# 48       R-G                No more carrying two lovely ladies.
# 49      Andy  wow, being sponsored by your mother would have...
# 50     Kevin         My priest accidentally logged in yesterday
# 51   Amilcar                               funny vine is a mess
# 52    Attila  she happens to be suspicious and I had all the...
# 53     Kevin      hmm i dont see emails to catch pokemon today?
# 54       R-G  I thought I had been confirmed? Some of these ...
# 55      Andy                  liek hockey but not in a restroom
# 56     Kevin  MARKOV IS RESUMING DIPLOMATIC RELATIONS WITH A...
# 57    Attila  humorous lemur was obligatory for the non-poli...
# 58     Kevin  Interestingly, I am really going live, remembe...
# 59     Carla                            u get chunks of course!
# 60       Roy                  just realized, my square is love?
# 61     Kevin                A stranger french-kissed your cheek
# 62   Amilcar  leave out of my queries. Do No Harm but my gir...
# 63       R-G  Guess who is watching the procession with the ...
# 64     Akira  oh i can keep on talking, then hitchhike to te...
# 65      Andy  oh shit I see your girlfriend at that point he...
# 66     Kevin  you put music from French Belgian Waffles in a...
# 67      Andy          I hope you never getting back from africa
# 68     Kevin                       WHOA BEN CARSON IS GHOST NOW
# 69    Lorant                    Sounds logical but not correct.
# 70     Kevin  hmm not quite, because Ecuador is a random hol...
# 71    Attila                I certainly not the best prey ever.
# 72     Dusan         hahahahaah nice kevin... your bot overload
#
# [73 rows x 2 columns]
